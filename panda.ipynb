# %%
import pandas as pd
import numpy as np

# %%
## what is dataframe
## how we can create dataframe, array, list, dictionory

dt = {"Name":['Ritu','Taniya','Abhishek','Tanmay','Mayank'],
      "Branch":['it','cse','it','ece','cse'],
      "Class":[2,3,4,1,2],
      "City":['jaipur','agra','vrindhavan','mathura','gokul']}
dt
# Out:
# {'Name': ['Ritu', 'Taniya', 'Abhishek', 'Tanmay', 'Mayank'],
#  'Branch': ['it', 'cse', 'it', 'ece', 'cse'],
#  'Class': [2, 3, 4, 1, 2],
#  'City': ['jaipur', 'agra', 'vrindhavan', 'mathura', 'gokul']}

# %%
#np.array(dt)
df = pd.DataFrame(dt)
df
# Out:
#        Name Branch  Class        City
# 0      Ritu     it      2      jaipur
# 1    Taniya    cse      3        agra
# 2  Abhishek     it      4  vrindhavan
# 3    Tanmay    ece      1     mathura
# 4    Mayank    cse      2       gokul

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Name']
# or df.Name
# Out:
# 0        Ritu
# 1      Taniya
# 2    Abhishek
# 3      Tanmay
# 4      Mayank
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# Name      object
# Branch    object
# Class      int64
# City      object
# dtype: object

# %%
df.shape
# Out:
# (5, 4)

# %%
df[['City','Name','Branch']]
# Out:
#          City      Name Branch
# 0      jaipur      Ritu     it
# 1        agra    Taniya    cse
# 2  vrindhavan  Abhishek     it
# 3     mathura    Tanmay    ece
# 4       gokul    Mayank    cse

# %%
df[1:3]
# Out:
#        Name Branch  Class        City
# 1    Taniya    cse      3        agra
# 2  Abhishek     it      4  vrindhavan

# %%
df[3:4]
# Out:
#      Name Branch  Class     City
# 3  Tanmay    ece      1  mathura

# %%
dfg=df[['Name','Branch']]
dfg[1:3]
# Out:
#        Name Branch
# 1    Taniya    cse
# 2  Abhishek     it

# %%
df.loc[1:2,['Name','Branch']]
# Out:
#        Name Branch
# 1    Taniya    cse
# 2  Abhishek     it

# %%
df.iloc[1:3,0:2]
# Out:
#        Name Branch
# 1    Taniya    cse
# 2  Abhishek     it

# %%
df.loc[3:,['Branch','Class','City']]
# Out:
#   Branch  Class     City
# 3    ece      1  mathura
# 4    cse      2    gokul

# %%
df.iloc[3:,1:]
# Out:
#   Branch  Class     City
# 3    ece      1  mathura
# 4    cse      2    gokul

# %%
# next day

# %%
import pandas as pdf

# %%
df = pdf.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail()
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.tail(10)
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
#df.brand.nunique()
#df['brand].nunique()
df.brand.unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# Yezdi                  1
# LML                    1
# Name: count, dtype: int64

# %%
# df['brand'] == "Kawasaki"
nippon_bike = df[df['brand'] == "Kawasaki"] #single condition

# %%
nippon_bike.head()
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
nippon_bike.shape
# Out:
# (79, 8)

# %%
# brand == kawasaki
# age == less than 2 year
# owner == First Owner

# (df['brand']=="Kawasaki") & (df['age']<=2) & (df['owner']=="First Owner")
japan=df[(df['brand']=="Kawasaki") & (df['age']<=2) & (df['owner']=="First Owner")]
japan
# Out:
#                    bike_name     price          city  kms_driven        owner  \
# 61             Kawasaki Z900  935000.0      Bagalkot      2500.0  First Owner
# 368     Kawasaki Ninja 650cc  600000.0  Bhubaneshwar       230.0  First Owner
# 846   Kawasaki Ninja 300 ABS  310000.0   Navi Mumbai      6000.0  First Owner
# 1348  Kawasaki Ninja 300 ABS  266600.0         Patna      2467.0  First Owner
# 1443  Kawasaki Ninja 300 ABS  266600.0         Patna      2467.0  First Owner
# 2263           Kawasaki Z650  499000.0        Mumbai      8000.0  First Owner
# 6883      Kawasaki Ninja 400  300000.0         Surat       190.0  First Owner
# 7411      Kawasaki Ninja 400  300000.0         Surat       190.0  First Owner
#
#       age  power     brand
# 61    2.0  900.0  Kawasaki
# 368   1.0  650.0  Kawasaki
# 846   2.0  300.0  Kawasaki
# 1348  2.0  300.0  Kawasaki
# 1443  2.0  300.0  Kawasaki
# 2263  2.0  650.0  Kawasaki
# 6883  2.0  400.0  Kawasaki
# 7411  2.0  400.0  Kawasaki

# %%
# japan['city'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 61          Bagalkot
# 368     Bhubaneshwar
# 846      Navi Mumbai
# 1348           Patna
# 1443           Patna
# 2263          Mumbai
# 6883           Surat
# 7411           Surat
# Name: city, dtype: object>

# %%
# japan['city'].nunique()
# japan.city.unique()
# Out:
# array(['Bagalkot', 'Bhubaneshwar', 'Navi Mumbai', 'Patna', 'Mumbai',
#        'Surat'], dtype=object)

# %%
bullet = df[df['brand'] == "Royal Enfield"]

# %%
bike=df[(df['city']=="Jaipur") & (df['age']<=2) & (df['owner']=="First Owner")]
bike
# Out:
#                                bike_name     price    city  kms_driven  \
# 47            Mahindra Centuro NXT 110cc   28000.0  Jaipur     45000.0
# 972                    Yamaha FZ25 250cc  105000.0  Jaipur     10468.0
# 1132  TVS Apache RTR 160 4V DISC ABS BS6   98000.0  Jaipur       749.0
# 1182                   Yamaha FZ25 250cc  105000.0  Jaipur     10468.0
# 2185       Bajaj Platina 110 H Gear Disc   43500.0  Jaipur     18346.0
# 3942                    Honda Livo 110cc   52000.0  Jaipur     12322.0
# 4525                    Honda Livo 110cc   52000.0  Jaipur     12322.0
# 4749                    Honda Livo 110cc   53214.0  Jaipur     15492.0
# 4781                    Honda Livo 110cc   53214.0  Jaipur     15492.0
# 6073                        KTM RC 200cc  190000.0  Jaipur      7902.0
# 6552                        KTM RC 200cc  190000.0  Jaipur      7902.0
# 7311                TVS Apache RTR 180cc   70000.0  Jaipur    207102.0
# ...

# %%
bike.shape
# Out:
# (13, 8)

# %%
bike = df[(df['brand'] == "KTM") | (df['brand'] == "JAWA")]

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (7324, 8)

# %%
bull = df[df['brand'] == "Royal Enfield"]
bull.shape
# Out:
# (1346, 8)

# %%
# bull.sort_values(by="price",ascending=False).head(20)
# Out:
#                                               bike_name     price  \
# 4912                 Royal Enfield Continental GT 650cc  285000.0
# 277                     Royal Enfield Interceptor 650cc  280000.0
# 2228                    Royal Enfield Interceptor 650cc  280000.0
# 1931                    Royal Enfield Interceptor 650cc  270000.0
# 5912                    Royal Enfield Interceptor 650cc  265500.0
# 1396                    Royal Enfield Interceptor 650cc  265000.0
# 428                     Royal Enfield Interceptor 650cc  265000.0
# 2332                    Royal Enfield Interceptor 650cc  265000.0
# 81                      Royal Enfield Interceptor 650cc  260000.0
# 1251                    Royal Enfield Interceptor 650cc  250000.0
# 1976                       Royal Enfield Standard 350cc  250000.0
# 5952                    Royal Enfield Thunderbird 350cc  250000.0
# 3089  Royal Enfield Classic Desert Storm 500cc Dual ...  239000.0
# ...

# %%
# find out or filter all the yamaha brand bike top ten lowest kms_driven bike of yamaha brand

# %%
yam=df[df['brand']=="Yamaha"]
yam
# Out:
#                                      bike_name     price         city  \
# 4         Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0    Bangalore
# 5                             Yamaha FZs 150cc   53499.0        Delhi
# 10                    Yamaha YZF-R15 2.0 150cc   72000.0    Bangalore
# 11                           Yamaha FZ25 250cc   95000.0    Bangalore
# 24                       Yamaha FZ V 2.0 150cc   45000.0        Delhi
# ...                                        ...       ...          ...
# 9284                         Yamaha FZ25 250cc  115800.0        Delhi
# 9318                        Yamaha Fazer 150cc   37000.0        Delhi
# 9336                       Yamaha YZF-R3 320cc  220000.0        Delhi
# 9342  Yamaha SZ RR V 2.0 150cc Limited Edition   55000.0         Pune
# 9345               Yamaha Fazer FI V 2.0 150cc   78000.0  Kanchipuram
#
#       kms_driven        owner  age  power   brand
# 4        10000.0  First Owner  3.0  150.0  Yamaha
# ...

# %%
yam.sort_values(by="kms_driven",ascending=True).head(10)
# Out:
#                        bike_name      price       city  kms_driven  \
# 628             Yamaha FZs 150cc    77500.0      Delhi        45.0
# 2264       Yamaha YZF-R1M 1000cc   600000.0  Faridabad       152.0
# 2037       Yamaha YZF-R1M 1000cc   600000.0      Surat       183.0
# 8693       Yamaha FZ25 ABS 250cc   142000.0      Delhi       233.0
# 4765        Yamaha YZF-R1 1000cc   850000.0   Guwahati       285.0
# 4200        Yamaha YZF-R1 1000cc   700000.0      Delhi       285.0
# 123          Yamaha YZF R6 600cc   500000.0  Bangalore       285.0
# 2265  Yamaha RX135 135cc 4-Speed    85000.0     Mumbai       300.0
# 8591        Yamaha YZF-R1 1000cc  1450000.0     Mumbai       340.0
# 5775     Yamaha FZ S V 2.0 150cc    65000.0       Pune       394.0
#
#             owner   age   power   brand
# 628   First Owner   3.0   150.0  Yamaha
# 2264  First Owner   5.0  1000.0  Yamaha
# 2037  First Owner   5.0  1000.0  Yamaha
# 8693  First Owner   2.0   250.0  Yamaha
# ...

# %%
jaipur_bull = bull[bull['city']=='Jaipur' ]
jaipur_bull
# Out:
#                                       bike_name     price    city  kms_driven  \
# 166                 Royal Enfield Classic 350cc  123600.0  Jaipur      7702.0
# 807                 Royal Enfield Classic 350cc  115000.0  Jaipur     25000.0
# 3009              Royal Enfield Himalayan 410cc  120000.0  Jaipur     14290.0
# 3332      Royal Enfield Classic 350cc Dual Disc  120000.0  Jaipur     21000.0
# 4497                Royal Enfield Classic 350cc  121000.0  Jaipur     20000.0
# 4630                Royal Enfield Classic 350cc   90000.0  Jaipur     15437.0
# 5193                Royal Enfield Electra 350cc   90000.0  Jaipur     14330.0
# 6326                Royal Enfield Classic 350cc  120000.0  Jaipur      2069.0
# 6655         Royal Enfield Classic Chrome 500cc  175000.0  Jaipur      7000.0
# 6807         Royal Enfield Classic Chrome 500cc  160000.0  Jaipur     14000.0
# 6897            Royal Enfield Thunderbird 350cc  135000.0  Jaipur     13500.0
# ...

# %%
jaipur_bull.to_csv('pink_bull.csv',index=False)

# %%
#single delete operation
jaipur_bull

# %%
#assignment -> filtering the data 
#assignment -> read excel files in panda

# %%
#next day - 19/07/24

# %%
import pandas as pdf
import numpy as np

# %%
data = {
    'A':[2,5,np.nan,8,np.nan,9],
    'B':[np.nan,45,np.nan,89,63,np.nan],
    'C':[np.nan,74,np.nan,np.nan,85,4],
    'D':[10,20,30,40,50,60]
}

# %%
df2 = pdf.DataFrame(data)
df2
# Out:
#      A     B     C   D
# 0  2.0   NaN   NaN  10
# 1  5.0  45.0  74.0  20
# 2  NaN   NaN   NaN  30
# 3  8.0  89.0   NaN  40
# 4  NaN  63.0  85.0  50
# 5  9.0   NaN   4.0  60

# %%
df2.dropna() #remove all rows containg missing values
# Out:
#      A     B     C   D
# 1  5.0  45.0  74.0  20

# %%
df2.dropna(axis='columns')
# Out:
#     D
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60

# %%
df2.isnull().sum()
# Out:
# A    2
# B    3
# C    3
# D    0
# dtype: int64

# %%
print('Total missing value in yor df: ',df2.isnull().sum().sum())
# Out:
# Total missing value in yor df:  8

# %%
df2.isnull().sum()/df2.shape[0]*100
#per(%) amount
# Out:
# A    33.333333
# B    50.000000
# C    50.000000
# D     0.000000
# dtype: float64

# %%
## filling the records
df2
# Out:
#      A     B     C   D
# 0  2.0   NaN   NaN  10
# 1  5.0  45.0  74.0  20
# 2  NaN   NaN   NaN  30
# 3  8.0  89.0   NaN  40
# 4  NaN  63.0  85.0  50
# 5  9.0   NaN   4.0  60

# %%
df2.fillna(500)
# Out:
#        A      B      C   D
# 0    2.0  500.0  500.0  10
# 1    5.0   45.0   74.0  20
# 2  500.0  500.0  500.0  30
# 3    8.0   89.0  500.0  40
# 4  500.0   63.0   85.0  50
# 5    9.0  500.0    4.0  60

# %%
#for diff col diff value
#A=500,B=600,C=700
df2['A'].fillna(500)
# Out:
# 0      2.0
# 1      5.0
# 2    500.0
# 3      8.0
# 4    500.0
# 5      9.0
# Name: A, dtype: float64

# %%
df2['B'].fillna(600)
# Out:
# 0    600.0
# 1     45.0
# 2    600.0
# 3     89.0
# 4     63.0
# 5    600.0
# Name: B, dtype: float64

# %%
df2['C'].fillna(700)
# Out:
# 0    700.0
# 1     74.0
# 2    700.0
# 3    700.0
# 4     85.0
# 5      4.0
# Name: C, dtype: float64

# %%
df2.mean()
# Out:
# A     6.000000
# B    65.666667
# C    54.333333
# D    35.000000
# dtype: float64

# %%
df2['A'].mean()
# Out:
# np.float64(6.0)

# %% [markdown]
# <h1>GroupBy</h1>

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df[df['brand']=='TVS']['price'].min()
# Out:
# np.float64(5800.0)

# %%
brand_group = df.groupby('brand')

# %%
# brand_group[['price']].min()
# brand_group[['price']].max()
# Out:
#                      price
# brand
# BMW              1800000.0
# Bajaj             195000.0
# Benelli           785000.0
# Ducati           1500000.0
# Harley-Davidson  1100000.0
# Hero              104000.0
# Honda             800000.0
# Hyosung           493500.0
# Ideal             100000.0
# Indian           1900000.0
# Jawa              223000.0
# KTM               860000.0
# Kawasaki         1100000.0
# LML                 4400.0
# MV               1500000.0
# Mahindra          175000.0
# Rajdoot            75000.0
# Royal Enfield     285000.0
# Suzuki           1260000.0
# TVS               224000.0
# Triumph          1300000.0
# Yamaha           1550000.0
# Yezdi              68000.0

# %%
brand_group['price'].agg(min_price='min',max_price='max',avg_price='mean')
# Out:
#                  min_price  max_price     avg_price
# brand
# BMW               255000.0  1800000.0  5.987500e+05
# Bajaj               6400.0   195000.0  4.833127e+04
# Benelli           110700.0   785000.0  2.942000e+05
# Ducati            380000.0  1500000.0  9.355455e+05
# Harley-Davidson   250000.0  1100000.0  4.529988e+05
# Hero                5000.0   104000.0  2.382945e+04
# Honda              10000.0   800000.0  5.923047e+04
# Hyosung           120000.0   493500.0  2.491678e+05
# Ideal             100000.0   100000.0  1.000000e+05
# Indian            700000.0  1900000.0  1.100000e+06
# Jawa              146000.0   223000.0  1.855000e+05
# KTM                55000.0   860000.0  1.746697e+05
# Kawasaki          110000.0  1100000.0  4.116246e+05
# LML                 4400.0     4400.0  4.400000e+03
# MV                950000.0  1500000.0  1.325000e+06
# Mahindra           17800.0   175000.0  7.250709e+04
# Rajdoot            75000.0    75000.0  7.500000e+04
# ...

# %%
brand_group['kms_driven'].agg(min_kms='min',max_kms='max',avg_kms='mean')
# Out:
#                  min_kms   max_kms       avg_kms
# brand
# BMW               2200.0   18000.0   8614.687500
# Bajaj               22.0  717794.0  29711.079818
# Benelli           1000.0   27000.0  12499.517857
# Ducati               3.0   31000.0   7224.909091
# Harley-Davidson    200.0   63000.0   4459.084125
# Hero                 1.0  750000.0  31977.075377
# Honda               68.0  654984.0  24034.615750
# Hyosung            210.0   51791.0   8891.859375
# Ideal            80000.0   80000.0  80000.000000
# Indian             172.0    1700.0    681.666667
# Jawa               381.0    2388.0   1396.000000
# KTM                 40.0  100000.0  14006.932219
# Kawasaki           180.0   36102.0   9538.848101
# LML              55000.0   55000.0  55000.000000
# MV                1911.0    6898.0   3202.250000
# Mahindra          1400.0   55000.0  21112.690909
# Rajdoot            500.0     500.0    500.000000
# Royal Enfield       40.0  300965.0  18275.558640
# ...

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
brand_group = df.groupby('owner')

# %%
brand_group['price'].agg(min_price='min',max_price='max',avg_price='mean')
# Out:
#                       min_price  max_price     avg_price
# owner
# First Owner              4400.0  1900000.0  69512.420037
# Fourth Owner Or More    11000.0   141000.0  61332.500000
# Second Owner             7500.0  1550000.0  53552.263651
# Third Owner              7000.0   699000.0  81431.916667

# %%
brand_group['kms_driven'].agg(min_kms='min',max_kms='max',avg_kms='mean')
# Out:
#                       min_kms   max_kms       avg_kms
# owner
# First Owner               3.0  750000.0  26474.521793
# Fourth Owner Or More   2009.0   60000.0  29173.333333
# Second Owner              1.0  300000.0  24465.370125
# Third Owner              23.0  101250.0  34606.138889

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
cat_col= df.select_dtypes(include='O')
cat_col.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
num_col= df.select_dtypes(exclude='O')
num_col.head()
# Out:
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
pd.concat([cat=col])
