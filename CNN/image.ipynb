# %%
import numpy as np
import cv2  # opencv
from PIL import Image # PIL <== pillow
import matplotlib.pyplot as plt

# %%
cat_img_path = r"C:\Users\chand\OneDrive\Documents\DS-Internship\DL\CNN\data\images\cats\cat_485.jpg"
cat = Image.open(cat_img_path)

# %%
cat
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
type(cat)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
catInPixel_form = np.array(cat)
catInPixel_form # pixels value - 0 to 255
# Out:
# array([[[ 17, 150, 227],
#         [ 17, 150, 227],
#         [ 18, 149, 227],
#         ...,
#         [155, 202, 232],
#         [156, 201, 232],
#         [156, 201, 232]],
#
#        [[ 19, 150, 228],
#         [ 19, 151, 226],
#         [ 19, 150, 228],
#         ...,
#         [160, 205, 236],
#         [160, 205, 234],
#         [161, 204, 236]],
#
#        [[ 22, 152, 228],
#         [ 22, 152, 227],
#         [ 23, 153, 229],
#         ...,
#         [166, 210, 239],
#         [166, 210, 237],
#         [168, 209, 239]],
#
#        ...,
#
#        [[ 72,  51,  34],
#         [ 79,  58,  41],
#         [ 91,  68,  50],
#         ...,
#         [196, 169, 140],
#         [196, 169, 140],
#         [196, 169, 140]],
#
#        [[ 74,  53,  36],
#         [ 81,  60,  43],
#         [ 94,  71,  53],
#         ...,
#         [195, 168, 139],
#         [195, 168, 139],
#         [195, 168, 139]],
#
#        [[ 78,  57,  40],
#         [ 85,  64,  47],
#         [ 97,  74,  56],
#         ...,
#         [195, 168, 139],
#         [195, 168, 139],
#         [195, 168, 139]]], dtype=uint8)

# %%
catInPixel_form.shape
# Out:
# (183, 275, 3)

# %%
catInPixel_form.min()
# Out:
# np.uint8(0)

# %%
import os

# %%
cat_dir = r"C:\Users\chand\OneDrive\Documents\DS-Internship\DL\CNN\data\images\cats"
dog_dir = r"C:\Users\chand\OneDrive\Documents\DS-Internship\DL\CNN\data\images\dogs"

# %%
# def get_image_paths(directory):
#     return [os.path.join(directory, filename) for filename in os.listdir(directory) if filename.endswith(('.png', '.jpg', '.jpeg'))]

# %%
path_dict = {
    'cats': [os.path.join(cat_dir, file) for file in os.listdir(cat_dir) if file.endswith(('.png', '.jpg', '.jpeg'))],
    'dogs': [os.path.join(dog_dir, file) for file in os.listdir(dog_dir) if file.endswith(('.png', '.jpg', '.jpeg'))]
}

# %%
print(path_dict)
# Out:
# {'cats': ['C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_1.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_10.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_100.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_101.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_102.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_103.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_104.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_106.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_109.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_11.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_111.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_113.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_114.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_116.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_118.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_119.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_12.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_120.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_123.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_124.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_129.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_13.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_132.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_133.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_134.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_137.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_138.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_139.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_14.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_140.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_141.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_146.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_147.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_148.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_149.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_15.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_151.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_152.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_153.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\cats\\cat_156.jpg', 'C:\\Users\\chand\\OneDrive\\Documents\\DS-Internship\\DL\\CNN\\data\\images\\ ...

# %%
os.listdir(r"C:\Users\chand\OneDrive\Documents\DS-Internship\DL\CNN\data\images\cats")
# Out:
# ['cat_1.jpg',
#  'cat_10.jpg',
#  'cat_100.jpg',
#  'cat_101.jpg',
#  'cat_102.jpg',
#  'cat_103.jpg',
#  'cat_104.jpg',
#  'cat_106.jpg',
#  'cat_109.jpg',
#  'cat_11.jpg',
#  'cat_111.jpg',
#  'cat_113.jpg',
#  'cat_114.jpg',
#  'cat_116.jpg',
#  'cat_118.jpg',
#  'cat_119.jpg',
#  'cat_12.jpg',
#  'cat_120.jpg',
#  'cat_123.jpg',
#  'cat_124.jpg',
#  'cat_129.jpg',
#  'cat_13.jpg',
#  'cat_132.jpg',
#  'cat_133.jpg',
#  'cat_134.jpg',
#  'cat_137.jpg',
#  'cat_138.jpg',
#  'cat_139.jpg',
#  'cat_14.jpg',
#  'cat_140.jpg',
#  'cat_141.jpg',
#  'cat_146.jpg',
#  'cat_147.jpg',
#  'cat_148.jpg',
#  'cat_149.jpg',
#  'cat_15.jpg',
#  'cat_151.jpg',
#  'cat_152.jpg',
#  'cat_153.jpg',
#  'cat_156.jpg',
#  'cat_158.jpg',
#  'cat_159.jpg',
#  'cat_16.jpg',
#  'cat_160.jpg',
#  'cat_161.jpg',
#  'cat_162.jpg',
#  'cat_163.jpg',
#  'cat_164.jpg',
#  'cat_165.jpg',
#  'cat_168.jpg',
#  'cat_169.jpg',
#  'cat_170.jpg',
#  'cat_172.jpg',
#  'cat_177.jpg',
#  'cat_179.jpg',
#  'cat_18.jpg',
#  'cat_180.jpg',
#  'cat_183.jpg',
#  'cat_184.jpg',
#  'cat_189.jpg',
#  'cat_190.jpg',
#  'cat_191.jpg',
#  'cat_194.jpg',
#  'cat_195.jpg',
#  'cat_198.jpg',
#  'cat_2.jpg',
#  'cat_200.jpg',
#  'cat_201.jpg',
#  'cat_202.jpg',
#  'cat_203.jpg',
#  'cat_207.jpg',
#  'cat_208.jpg',
#  'cat_209.jpg',
#  'cat_21.jpg',
#  'cat_211.jpg',
#  'cat_213.jpg',
#  'cat_214.jpg',
#  'cat_215.jpg',
#  'cat_217.jpg',
#  'cat_218.jpg',
#  'cat_219.jpg',
#  'cat_220.jpg',
#  'cat_221.jpg',
#  'cat_222.jpg',
#  'cat_223.jpg',
#  'cat_224.jpg',
#  'cat_225.jpg',
#  'cat_227.jpg',
#  'cat_228.jpg',
#  'cat_229.jpg',
#  'cat_230.jpg',
#  'cat_232.jpg',
#  'cat_234.jpg',
#  'cat_235.jpg',
#  'cat_238.jpg',
#  'cat_24.jpg',
#  'cat_240.jpg',
#  'cat_243.jpg',
#  'cat_244.jpg',
#  'cat_246.jpg',
#  'cat_247.jpg',
#  'cat_248.jpg',
#  'cat_251.jpg',
#  'cat_253.jpg',
#  'cat_255.jpg',
#  'cat_257.jpg',
#  'cat_26.jpg',
#  'cat_260.jpg',
#  'cat_261.jpg',
#  'cat_263.jpg',
#  'cat_265.jpg',
#  'cat_268.jpg',
#  'cat_269.jpg',
#  'cat_27.jpg',
#  'cat_270.jpg',
#  'cat_271.jpg',
#  'cat_273.jpg',
#  'cat_274.jpg',
#  'cat_275.jpg',
#  'cat_276.jpg',
#  'cat_279.jpg',
#  'cat_280.jpg',
#  'cat_281.jpg',
#  'cat_284.jpg',
#  'cat_285.jpg',
#  'cat_289.jpg',
#  'cat_290.jpg',
#  'cat_292.jpg',
#  'cat_293.jpg',
#  'cat_297.jpg',
#  'cat_298.jpg',
#  'cat_3.jpg',
#  'cat_303.jpg',
#  'cat_304.jpg',
#  'cat_306.jpg',
#  'cat_307.jpg',
#  'cat_310.jpg',
#  'cat_311.jpg',
#  'cat_313.jpg',
#  'cat_316.jpg',
#  'cat_317.jpg',
#  'cat_318.jpg',
#  'cat_320.jpg',
#  'cat_321.jpg',
#  'cat_325.jpg',
#  'cat_327.jpg',
#  'cat_329.jpg',
#  'cat_33.jpg',
#  'cat_330.jpg',
#  'cat_331.jpg',
#  'cat_332.jpg',
#  'cat_333.jpg',
#  'cat_336.jpg',
#  'cat_34.jpg',
#  'cat_341.jpg',
#  'cat_342.jpg',
#  'cat_343.jpg',
#  'cat_344.jpg',
#  'cat_345.jpg',
#  'cat_348.jpg',
#  'cat_35.jpg',
#  'cat_350.jpg',
#  'cat_351.jpg',
#  'cat_352.jpg',
#  'cat_355.jpg',
#  'cat_358.jpg',
#  'cat_359.jpg',
#  'cat_361.jpg',
#  'cat_362.jpg',
#  'cat_363.jpg',
#  'cat_367.jpg',
#  'cat_369.jpg',
#  'cat_37.jpg',
#  'cat_370.jpg',
#  'cat_371.jpg',
#  'cat_372.jpg',
#  'cat_373.jpg',
#  'cat_375.jpg',
#  'cat_376.jpg',
#  'cat_377.jpg',
#  'cat_38.jpg',
#  'cat_380.jpg',
#  'cat_381.jpg',
#  'cat_384.jpg',
#  'cat_385.jpg',
#  'cat_386.jpg',
#  'cat_387.jpg',
#  'cat_388.jpg',
#  'cat_39.jpg',
#  'cat_391.jpg',
#  'cat_393.jpg',
#  'cat_395.jpg',
#  'cat_396.jpg',
#  'cat_397.jpg',
#  'cat_399.jpg',
#  'cat_4.jpg',
#  'cat_400.jpg',
#  'cat_402.jpg',
#  'cat_403.jpg',
#  'cat_405.jpg',
#  'cat_407.jpg',
#  'cat_408.jpg',
#  'cat_413.jpg',
#  'cat_414.jpg',
#  'cat_416.jpg',
#  'cat_417.jpg',
#  'cat_418.jpg',
#  'cat_419.jpg',
#  'cat_42.jpg',
#  'cat_420.jpg',
#  'cat_422.jpg',
#  'cat_423.jpg',
#  'cat_426.jpg',
#  'cat_427.jpg',
#  'cat_428.jpg',
#  'cat_429.jpg',
#  'cat_43.jpg',
#  'cat_430.jpg',
#  'cat_433.jpg',
#  'cat_434.jpg',
#  'cat_435.jpg',
#  'cat_438.jpg',
#  'cat_440.jpg',
#  'cat_443.jpg',
#  'cat_445.jpg',
#  'cat_446.jpg',
#  'cat_450.jpg',
#  'cat_452.jpg',
#  'cat_453.jpg',
#  'cat_455.jpg',
#  'cat_456.jpg',
#  'cat_46.jpg',
#  'cat_461.jpg',
#  'cat_463.jpg',
#  'cat_464.jpg',
#  'cat_465.jpg',
#  'cat_466.jpg',
#  'cat_467.jpg',
#  'cat_468.jpg',
#  'cat_469.jpg',
#  'cat_473.jpg',
#  'cat_474.jpg',
#  'cat_482.jpg',
#  'cat_483.jpg',
#  'cat_485.jpg',
#  'cat_487.jpg',
#  'cat_489.jpg',
#  'cat_49.jpg',
#  'cat_490.jpg',
#  'cat_492.jpg',
#  'cat_493.jpg',
#  'cat_494.jpg',
#  'cat_495.jpg',
#  'cat_496.jpg',
#  'cat_497.jpg',
#  'cat_498.jpg',
#  'cat_499.jpg',
#  'cat_5.jpg',
#  'cat_50.jpg',
#  'cat_500.jpg',
#  'cat_504.jpg',
#  'cat_505.jpg',
#  'cat_506.jpg',
#  'cat_508.jpg',
#  'cat_510.jpg',
#  'cat_511.jpg',
#  'cat_518.jpg',
#  'cat_519.jpg',
#  'cat_52.jpg',
#  'cat_520.jpg',
#  'cat_523.jpg',
#  'cat_524.jpg',
#  'cat_525.jpg',
#  'cat_526.jpg',
#  'cat_528.jpg',
#  'cat_53.jpg',
#  'cat_531.jpg',
#  'cat_532.jpg',
#  'cat_533.jpg',
#  'cat_535.jpg',
#  'cat_536.jpg',
#  'cat_538.jpg',
#  'cat_54.jpg',
#  'cat_540.jpg',
#  'cat_542.jpg',
#  'cat_543.jpg',
#  'cat_544.jpg',
#  'cat_545.jpg',
#  'cat_546.jpg',
#  'cat_547.jpg',
#  'cat_548.jpg',
#  'cat_549.jpg',
#  'cat_551.jpg',
#  'cat_553.jpg',
#  'cat_556.jpg',
#  'cat_557.jpg',
#  'cat_558.jpg',
#  'cat_559.jpg',
#  'cat_56.jpg',
#  'cat_560.jpg',
#  'cat_564.jpg',
#  'cat_565.jpg',
#  'cat_567.jpg',
#  'cat_569.jpg',
#  'cat_570.jpg',
#  'cat_573.jpg',
#  'cat_574.jpg',
#  'cat_575.jpg',
#  'cat_577.jpg',
#  'cat_58.jpg',
#  'cat_580.jpg',
#  'cat_581.jpg',
#  'cat_583.jpg',
#  'cat_585.jpg',
#  'cat_586.jpg',
#  'cat_587.jpg',
#  'cat_589.jpg',
#  'cat_59.jpg',
#  'cat_590.jpg',
#  'cat_591.jpg',
#  'cat_592.jpg',
#  'cat_595.jpg',
#  'cat_6.jpg',
#  'cat_60.jpg',
#  'cat_601.jpg',
#  'cat_602.jpg',
#  'cat_604.jpg',
#  'cat_605.jpg',
#  'cat_61.jpg',
#  'cat_64.jpg',
#  'cat_66.jpg',
#  'cat_67.jpg',
#  'cat_69.jpg',
#  'cat_70.jpg',
#  'cat_74.jpg',
#  'cat_75.jpg',
#  'cat_77.jpg',
#  'cat_78.jpg',
#  'cat_80.jpg',
#  'cat_84.jpg',
#  'cat_87.jpg',
#  'cat_88.jpg',
#  'cat_9.jpg',
#  'cat_93.jpg',
#  'cat_94.jpg',
#  'cat_95.jpg',
#  'cat_96.jpg',
#  'cat_97.jpg',
#  'cat_98.jpg']

# %%
from pathlib import Path
path_dict = {'cats':[],'dogs':[]}
base_directory = r"./Data/images"

for dir_name in os.listdir(base_directory):  # cats , dogs 
    dir_path = Path(os.path.join(base_directory,dir_name))
    print(dir_path)
    for image_name in os.listdir(dir_path):  
        # print(os.path.join(dir_path,image_name)) 
        path_dict[dir_name].append(os.path.join(str(dir_path),image_name))
        # path_dict[dir_path].append(os.path.join(dir_path,image_name))
# Out:
# Data\images\cats
# Data\images\dogs

# %%
Image.open(path_dict['cats'][100])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
cv2.imread(path_dict['dogs'][50])
# Out:
# array([[[216, 211, 213],
#         [216, 211, 213],
#         [216, 211, 213],
#         ...,
#         [179, 193, 205],
#         [179, 193, 205],
#         [179, 193, 205]],
#
#        [[218, 213, 215],
#         [217, 212, 214],
#         [217, 212, 214],
#         ...,
#         [180, 194, 206],
#         [179, 193, 205],
#         [179, 193, 205]],
#
#        [[219, 214, 216],
#         [219, 214, 216],
#         [218, 213, 215],
#         ...,
#         [180, 194, 206],
#         [179, 193, 205],
#         [179, 193, 205]],
#
#        ...,
#
#        [[197, 200, 215],
#         [197, 200, 215],
#         [198, 201, 216],
#         ...,
#         [202, 210, 217],
#         [204, 210, 215],
#         [203, 209, 214]],
#
#        [[194, 197, 212],
#         [194, 197, 212],
#         [194, 197, 212],
#         ...,
#         [200, 208, 215],
#         [201, 207, 212],
#         [201, 207, 212]],
#
#        [[195, 198, 213],
#         [195, 198, 213],
#         [195, 198, 213],
#         ...,
#         [199, 207, 214],
#         [200, 206, 211],
#         [200, 206, 211]]], dtype=uint8)

# %%
x = []   # img in array after reduce the size
y = []   # label

sample_img = cv2.imread(path_dict['dogs'][256])
reduced_img = cv2.resize(sample_img,(224,224))
reduced_img.shape
# Out:
# (224, 224, 3)

# %%
for class_name, paths in path_dict.items():
    for path in paths:
        sample_img = cv2.imread(path)
        reduced_img = cv2.resize(sample_img,(224,224))
        x.append(reduced_img)
        y.append(class_name)

# %%
len(x)   , len(y)
# Out:
# (697, 697)

# %%
set(y)
# Out:
# {'cats', 'dogs'}

# %%
Y = []
for item in y:
    if item == "cats":
        Y.append(1)
    else:
        Y.append(0)

# %%
Y = [1 if item == "cats" else 0 for item in y]

# %%
set(Y)
# Out:
# {0, 1}

# %%
X = np.array(x)
Y = np.array(Y)

# %%
X.ndim
# Out:
# 4

# %%
type(X)  ,  type(Y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
X.shape
#679 images
# size 224 height , 224 width , 3channel (rgb)
# Out:
# (697, 224, 224, 3)

# %%
X[0]
# Out:
# array([[[156, 141,  92],
#         [159, 144, 102],
#         [159, 145, 112],
#         ...,
#         [152, 142,  75],
#         [156, 144,  80],
#         [160, 148,  84]],
#
#        [[151, 136,  87],
#         [155, 140,  97],
#         [157, 143, 107],
#         ...,
#         [151, 140,  75],
#         [154, 142,  77],
#         [157, 145,  81]],
#
#        [[150, 136,  86],
#         [155, 141,  96],
#         [155, 140, 102],
#         ...,
#         [151, 139,  75],
#         [153, 141,  77],
#         [157, 145,  81]],
#
#        ...,
#
#        [[ 81,  90,  99],
#         [ 77,  86,  95],
#         [ 79,  88,  97],
#         ...,
#         [ 37,  42,  60],
#         [ 39,  42,  57],
#         [ 40,  43,  58]],
#
#        [[ 52,  59,  59],
#         [ 54,  60,  61],
#         [ 51,  57,  58],
#         ...,
#         [ 40,  44,  59],
#         [ 42,  45,  60],
#         [ 43,  46,  61]],
#
#        [[ 37,  41,  36],
#         [ 33,  37,  34],
#         [ 35,  38,  35],
#         ...,
#         [ 40,  43,  56],
#         [ 37,  40,  55],
#         [ 34,  37,  52]]], dtype=uint8)

# %%
plt.imshow(X[450])
plt.title(y[450])
plt.axis('off')
plt.show()

# %%
x[455].shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(np.random.randint(0,255,(224,224,3)))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))

# %%
X = X/255.0

# %%
# diff method
# from sklearn.preprocessing import MinMaxScaler , StandardScaler

# %%
X
# Out:
# array([[[[0.61176471, 0.55294118, 0.36078431],
#          [0.62352941, 0.56470588, 0.4       ],
#          [0.62352941, 0.56862745, 0.43921569],
#          ...,
#          [0.59607843, 0.55686275, 0.29411765],
#          [0.61176471, 0.56470588, 0.31372549],
#          [0.62745098, 0.58039216, 0.32941176]],
#
#         [[0.59215686, 0.53333333, 0.34117647],
#          [0.60784314, 0.54901961, 0.38039216],
#          [0.61568627, 0.56078431, 0.41960784],
#          ...,
#          [0.59215686, 0.54901961, 0.29411765],
#          [0.60392157, 0.55686275, 0.30196078],
#          [0.61568627, 0.56862745, 0.31764706]],
#
#         [[0.58823529, 0.53333333, 0.3372549 ],
#          [0.60784314, 0.55294118, 0.37647059],
#          [0.60784314, 0.54901961, 0.4       ],
#          ...,
#          [0.59215686, 0.54509804, 0.29411765],
#          [0.6       , 0.55294118, 0.30196078],
#          [0.61568627, 0.56862745, 0.31764706]],
#
#         ...,
#
#         [[0.31764706, 0.35294118, 0.38823529],
#          [0.30196078, 0.3372549 , 0.37254902],
#          [0.30980392, 0.34509804, 0.38039216],
#          ...,
#          [0.14509804, 0.16470588, 0.23529412],
#          [0.15294118, 0.16470588, 0.22352941],
#          [0.15686275, 0.16862745, 0.22745098]],
#
#         [[0.20392157, 0.23137255, 0.23137255],
#          [0.21176471, 0.23529412, 0.23921569],
#          [0.2       , 0.22352941, 0.22745098],
#          ...,
#          [0.15686275, 0.17254902, 0.23137255],
#          [0.16470588, 0.17647059, 0.23529412],
#          [0.16862745, 0.18039216, 0.23921569]],
#
#         [[0.14509804, 0.16078431, 0.14117647],
#          [0.12941176, 0.14509804, 0.13333333],
#          [0.1372549 , 0.14901961, 0.1372549 ],
#          ...,
#          [0.15686275, 0.16862745, 0.21960784],
#          [0.14509804, 0.15686275, 0.21568627],
#          [0.13333333, 0.14509804, 0.20392157]]],
#
#
#        [[[0.70980392, 0.72156863, 0.68627451],
#          [0.6627451 , 0.6745098 , 0.63921569],
#          [0.67058824, 0.68235294, 0.64705882],
#          ...,
#          [0.40392157, 0.4745098 , 0.61960784],
#          [0.44705882, 0.52156863, 0.65882353],
#          [0.41960784, 0.49411765, 0.63529412]],
#
#         [[0.71764706, 0.72941176, 0.69411765],
#          [0.66666667, 0.67843137, 0.64313725],
#          [0.67058824, 0.68235294, 0.64705882],
#          ...,
#          [0.43529412, 0.50588235, 0.65098039],
#          [0.46666667, 0.54509804, 0.67843137],
#          [0.38431373, 0.45882353, 0.59607843]],
#
#         [[0.69019608, 0.70196078, 0.66666667],
#          [0.69803922, 0.70980392, 0.6745098 ],
#          [0.70980392, 0.72156863, 0.68627451],
#          ...,
#          [0.42352941, 0.49411765, 0.63921569],
#          [0.39215686, 0.46666667, 0.60392157],
#          [0.40784314, 0.48235294, 0.61960784]],
#
#         ...,
#
#         [[0.70588235, 0.72941176, 0.75686275],
#          [0.70196078, 0.7254902 , 0.75294118],
#          [0.73333333, 0.74509804, 0.77647059],
#          ...,
#          [0.83137255, 0.81960784, 0.80392157],
#          [0.80784314, 0.79607843, 0.78039216],
#          [0.8       , 0.78823529, 0.77254902]],
#
#         [[0.70980392, 0.72156863, 0.7372549 ],
#          [0.7254902 , 0.7372549 , 0.75294118],
#          [0.74117647, 0.74509804, 0.76470588],
#          ...,
#          [0.81960784, 0.80784314, 0.79215686],
#          [0.78823529, 0.77647059, 0.76078431],
#          [0.78039216, 0.76862745, 0.75294118]],
#
#         [[0.74117647, 0.74117647, 0.74117647],
#          [0.75294118, 0.75294118, 0.75294118],
#          [0.74117647, 0.74509804, 0.74901961],
#          ...,
#          [0.81176471, 0.8       , 0.78431373],
#          [0.80784314, 0.79607843, 0.78039216],
#          [0.80784314, 0.8       , 0.78039216]]],
#
#
#        [[[0.98039216, 0.94117647, 0.91372549],
#          [0.98039216, 0.94117647, 0.91372549],
#          [0.98039216, 0.94117647, 0.91372549],
#          ...,
#          [0.03529412, 0.04313725, 0.04705882],
#          [0.03529412, 0.04313725, 0.04313725],
#          [0.03529412, 0.04313725, 0.04313725]],
#
#         [[0.98039216, 0.94117647, 0.91372549],
#          [0.98039216, 0.94117647, 0.91372549],
#          [0.98039216, 0.94117647, 0.91372549],
#          ...,
#          [0.03529412, 0.04313725, 0.04705882],
#          [0.03529412, 0.04313725, 0.04313725],
#          [0.03529412, 0.04313725, 0.04313725]],
#
#         [[0.98039216, 0.94117647, 0.91372549],
#          [0.98039216, 0.94117647, 0.91372549],
#          [0.98039216, 0.94117647, 0.91372549],
#          ...,
#          [0.03529412, 0.04313725, 0.04705882],
#          [0.03529412, 0.04313725, 0.04313725],
#          [0.03529412, 0.04313725, 0.04313725]],
#
#         ...,
#
#         [[0.4745098 , 0.43529412, 0.48627451],
#          [0.4627451 , 0.42352941, 0.4745098 ],
#          [0.44705882, 0.40784314, 0.45882353],
#          ...,
#          [0.09803922, 0.07843137, 0.08235294],
#          [0.09411765, 0.0745098 , 0.07843137],
#          [0.09411765, 0.0745098 , 0.07843137]],
#
#         [[0.47843137, 0.43921569, 0.49019608],
#          [0.45882353, 0.41960784, 0.4745098 ],
#          [0.44313725, 0.40392157, 0.45490196],
#          ...,
#          [0.09411765, 0.0745098 , 0.07843137],
#          [0.09411765, 0.0745098 , 0.07843137],
#          [0.09411765, 0.0745098 , 0.07843137]],
#
#         [[0.47843137, 0.44313725, 0.49019608],
#          [0.45882353, 0.41960784, 0.47058824],
#          [0.43921569, 0.4       , 0.44705882],
#          ...,
#          [0.09019608, 0.07058824, 0.07843137],
#          [0.09019608, 0.07058824, 0.0745098 ],
#          [0.09019608, 0.07058824, 0.0745098 ]]],
#
#
#        ...,
#
#
#        [[[0.58823529, 0.4       , 0.39607843],
#          [0.55686275, 0.36862745, 0.36470588],
#          [0.6627451 , 0.4745098 , 0.47058824],
#          ...,
#          [0.26666667, 0.35294118, 0.30588235],
#          [0.26666667, 0.35294118, 0.30588235],
#          [0.26666667, 0.35294118, 0.30588235]],
#
#         [[0.55294118, 0.36470588, 0.36078431],
#          [0.52941176, 0.34117647, 0.3372549 ],
#          [0.63529412, 0.44705882, 0.44313725],
#          ...,
#          [0.26666667, 0.35294118, 0.30588235],
#          [0.26666667, 0.35294118, 0.30588235],
#          [0.26666667, 0.35294118, 0.30588235]],
#
#         [[0.5372549 , 0.34901961, 0.34509804],
#          [0.5254902 , 0.3372549 , 0.33333333],
#          [0.61960784, 0.43137255, 0.42745098],
#          ...,
#          [0.26666667, 0.35294118, 0.30588235],
#          [0.26666667, 0.35294118, 0.30588235],
#          [0.26666667, 0.35294118, 0.30588235]],
#
#         ...,
#
#         [[0.41960784, 0.48235294, 0.66666667],
#          [0.44313725, 0.50588235, 0.69019608],
#          [0.44705882, 0.50588235, 0.69411765],
#          ...,
#          [0.21176471, 0.4       , 0.41568627],
#          [0.21176471, 0.4       , 0.41568627],
#          [0.21176471, 0.4       , 0.41568627]],
#
#         [[0.43137255, 0.49411765, 0.67843137],
#          [0.44705882, 0.50980392, 0.69411765],
#          [0.44313725, 0.50196078, 0.69411765],
#          ...,
#          [0.21176471, 0.4       , 0.41568627],
#          [0.21176471, 0.4       , 0.41568627],
#          [0.21176471, 0.4       , 0.41568627]],
#
#         [[0.45098039, 0.51372549, 0.69803922],
#          [0.45882353, 0.52156863, 0.70588235],
#          [0.44313725, 0.49803922, 0.69019608],
#          ...,
#          [0.21176471, 0.40392157, 0.41176471],
#          [0.21176471, 0.40392157, 0.41176471],
#          [0.21176471, 0.40392157, 0.41176471]]],
#
#
#        [[[0.12156863, 0.22352941, 0.17254902],
#          [0.12156863, 0.21568627, 0.16862745],
#          [0.11764706, 0.20392157, 0.15686275],
#          ...,
#          [0.18431373, 0.36862745, 0.3372549 ],
#          [0.18431373, 0.35686275, 0.32941176],
#          [0.17647059, 0.34901961, 0.32156863]],
#
#         [[0.11372549, 0.21568627, 0.17647059],
#          [0.11764706, 0.21176471, 0.17254902],
#          [0.11372549, 0.19607843, 0.16078431],
#          ...,
#          [0.18431373, 0.36862745, 0.3372549 ],
#          [0.19215686, 0.36470588, 0.33333333],
#          [0.18431373, 0.35686275, 0.32941176]],
#
#         [[0.11764706, 0.21568627, 0.18431373],
#          [0.11764706, 0.20784314, 0.17647059],
#          [0.12156863, 0.20392157, 0.17254902],
#          ...,
#          [0.19607843, 0.38431373, 0.35294118],
#          [0.20392157, 0.37647059, 0.34509804],
#          [0.18823529, 0.36078431, 0.33333333]],
#
#         ...,
#
#         [[0.56078431, 0.63529412, 0.71764706],
#          [0.54117647, 0.61176471, 0.70196078],
#          [0.52156863, 0.58823529, 0.68627451],
#          ...,
#          [0.52156863, 0.61176471, 0.69803922],
#          [0.51764706, 0.6       , 0.68235294],
#          [0.50588235, 0.58823529, 0.67058824]],
#
#         [[0.55686275, 0.63529412, 0.70196078],
#          [0.5254902 , 0.6       , 0.68235294],
#          [0.50980392, 0.58039216, 0.67058824],
#          ...,
#          [0.49803922, 0.59215686, 0.67058824],
#          [0.49411765, 0.56862745, 0.65098039],
#          [0.49019608, 0.56862745, 0.65098039]],
#
#         [[0.52941176, 0.60784314, 0.6745098 ],
#          [0.51372549, 0.59215686, 0.6627451 ],
#          [0.49411765, 0.56862745, 0.65098039],
#          ...,
#          [0.48235294, 0.57647059, 0.64705882],
#          [0.49411765, 0.56078431, 0.64313725],
#          [0.46666667, 0.5372549 , 0.61960784]]],
#
#
#        [[[0.11764706, 0.28627451, 0.36862745],
#          [0.12156863, 0.28627451, 0.37254902],
#          [0.1372549 , 0.30588235, 0.38823529],
#          ...,
#          [0.18823529, 0.39215686, 0.43921569],
#          [0.17647059, 0.37254902, 0.41568627],
#          [0.18823529, 0.39215686, 0.43137255]],
#
#         [[0.16470588, 0.33333333, 0.41568627],
#          [0.15294118, 0.32156863, 0.40392157],
#          [0.15294118, 0.31764706, 0.4       ],
#          ...,
#          [0.17254902, 0.37647059, 0.42352941],
#          [0.17254902, 0.37254902, 0.41176471],
#          [0.18823529, 0.38823529, 0.42745098]],
#
#         [[0.21960784, 0.38431373, 0.4745098 ],
#          [0.19215686, 0.36078431, 0.44705882],
#          [0.17254902, 0.3372549 , 0.42352941],
#          ...,
#          [0.14901961, 0.34901961, 0.4       ],
#          [0.16470588, 0.36470588, 0.4       ],
#          [0.18431373, 0.37647059, 0.41176471]],
#
#         ...,
#
#         [[0.01176471, 0.09803922, 0.09019608],
#          [0.01568627, 0.10196078, 0.09411765],
#          [0.01176471, 0.09803922, 0.09019608],
#          ...,
#          [0.00392157, 0.04705882, 0.04313725],
#          [0.00784314, 0.04313725, 0.03529412],
#          [0.00784314, 0.03921569, 0.03529412]],
#
#         [[0.02352941, 0.10980392, 0.10196078],
#          [0.01960784, 0.10588235, 0.09803922],
#          [0.00784314, 0.09411765, 0.08627451],
#          ...,
#          [0.        , 0.04313725, 0.04313725],
#          [0.00392157, 0.03921569, 0.03529412],
#          [0.00784314, 0.03921569, 0.03529412]],
#
#         [[0.03137255, 0.11764706, 0.10980392],
#          [0.02352941, 0.10980392, 0.10196078],
#          [0.00784314, 0.09411765, 0.08627451],
#          ...,
#          [0.        , 0.04705882, 0.03921569],
#          [0.00392157, 0.03921569, 0.03529412],
#          [0.00784314, 0.03921569, 0.03529412]]]])

# %%
plt.imshow(x[255])
plt.title(y[255])
plt.axis('off')
plt.show()

# %%
plt.imshow(X[255])
plt.title(Y[255])
plt.axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.15,random_state=42)

# %%
### CNN model defining
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
# from tensorflow.keras.layers import Dense, Conv2D

# %%
cnn_model = Sequential([
    # Convolutional layers
    layers.Conv2D(64, (3,3), activation='relu', input_shape=(224, 224, 3)),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(40, (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(30, (3,3), activation='relu'),

    #flattening layer
    layers.Flatten(),

    # Dense layers for classification
    layers.Dense(45, activation='relu'),
    layers.Dense(24, activation='relu'),
layers.Dense(1, activation='sigmoid')
])

# Compile the model
cnn_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Print model summary for a detailed overview
cnn_model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 40)   │        23,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 40)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 30)     │        10,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 81120)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 45)             │     3,650,445 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         1,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            25 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,687,276 (14.07 MB)
#  Trainable params: 3,687,276 (14.07 MB)
#  Non-trainable params: 0 (0.00 B)
